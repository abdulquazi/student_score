# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
df=pd.read_csv('')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 #load dataset
# ----> 2 df=pd.read_csv('Downloads/Student Performance Data1 Aac.csv')
#       3 df
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Downloads/Student Performance Data1 Aac.csv'

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Previous_Scores  Tutoring_Sessions  Sleep_Hours  \
# 0              7          53               58                  3            8
# 1              4          53               99                  1            8
# 2             60          55               88                  2            9
# 3              8          46               93                  2           20
# 4              5          71               53                  0            5
#
#   Motivation_Level Teacher_Quality School_Type Internet_Access Family_Income  \
# 0             high            Poor      Public              No        Medium
# 1              LOW         Average     Private             Yes           Low
# 2           Medium            Poor     Private              No           Low
# 3             High            Good     Private             Yes        Medium
# 4             High            Good     Private              No        Medium
#
#   Parental_Involvement Parental_Education_Level  Distance_from_Home  \
# 0                 High                      NaN                28.0
# 1                 High                   School                 NaN
# 2               Medium                   School                 NaN
# 3                  Low                 Graduate                 3.0
# 4               Medium             Postgraduate                20.0
#
#    Physical_Activity Peer_Influence Access_to_Resources  \
# 0                  1       Positive                 Low
# 1                  2        Neutral                 Low
# 2                  3        Neutral                 Low
# 3                  3       Negative                 Low
# 4                  4       Positive                High
#
#   Extracurricular_Activities  Health Study_Environment  Exam_Score
# 0                        Yes       1           Average          63
# 1                        Yes       2              Good          79
# 2                         No       4              Poor          95
# 3                         No       2              Poor          93
# 4                        Yes       1              Poor          68

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance  Previous_Scores  Tutoring_Sessions  \
# 6603              7          45               81                  2
# 6604              5          58               79                  2
# 6605              7          82               63                  1
# 6606              2          80               65                  4
# 6607              4          92               90                  3
#
#       Sleep_Hours Motivation_Level Teacher_Quality School_Type  \
# 6603            4           Medium         Average      Public
# 6604            7              Low         Average     Private
# 6605            7           Medium         Average      Public
# 6606            7           Medium             NaN     Private
# 6607            8           Medium            Good     Private
#
#      Internet_Access Family_Income Parental_Involvement  \
# 6603             Yes        Medium                 High
# 6604              No           Low                  Low
# 6605             Yes        Medium                 High
# 6606             Yes           Low                  Low
# 6607              No           Low                  Low
#
#      Parental_Education_Level  Distance_from_Home  Physical_Activity  \
# 6603                 Graduate                 3.0                  1
# 6604                   School                16.0                  0
# 6605                   School                15.0                  2
# 6606                   School                 5.0                  2
# 6607                 Graduate                14.0                  1
#
#      Peer_Influence Access_to_Resources Extracurricular_Activities  Health  \
# 6603       Positive              Medium                         No       3
# 6604        Neutral              Medium                        Yes       5
# 6605       Negative                 Low                         No       4
# 6606       Negative              Medium                         No       1
# 6607        Neutral                High                        Yes       3
#
#      Study_Environment  Exam_Score
# 6603           Average          68
# 6604           Average          67
# 6605           Average          71
# 6606              Good          65
# 6607              Poor          93

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Previous_Scores', 'Tutoring_Sessions',
#        'Sleep_Hours', 'Motivation_Level', 'Teacher_Quality', 'School_Type',
#        'Internet_Access', 'Family_Income', 'Parental_Involvement',
#        'Parental_Education_Level', 'Distance_from_Home', 'Physical_Activity',
#        'Peer_Influence', 'Access_to_Resources', 'Extracurricular_Activities',
#        'Health', 'Study_Environment', 'Exam_Score'],
#       dtype='str')

# %%
df.shape
# Out:
# (6608, 20)

# %%
df.mean(numeric_only=True)
# Out:
# Hours_Studied          5.973214
# Attendance            69.132718
# Previous_Scores       64.318856
# Tutoring_Sessions      2.006810
# Sleep_Hours            6.023608
# Distance_from_Home    14.857239
# Physical_Activity      2.978208
# Health                 2.980478
# Exam_Score            70.530418
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#    Hours_Studied  Attendance  Previous_Scores  Tutoring_Sessions  Sleep_Hours  \
# 0              6          65               44                  3            7
#
#    Distance_from_Home  Physical_Activity  Health  Exam_Score
# 0                20.0                  1       1          69

# %%
df.median(numeric_only=True)
# Out:
# Hours_Studied          6.0
# Attendance            69.0
# Previous_Scores       64.0
# Tutoring_Sessions      2.0
# Sleep_Hours            6.0
# Distance_from_Home    15.0
# Physical_Activity      3.0
# Health                 3.0
# Exam_Score            71.0
# dtype: float64

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Previous_Scores  Tutoring_Sessions  \
# count    6608.000000  6608.000000      6608.000000        6608.000000
# mean        5.973214    69.132718        64.318856           2.006810
# std         3.221838    17.311517        20.100155           1.413715
# min         1.000000    40.000000        30.000000           0.000000
# 25%         3.000000    54.000000        47.000000           1.000000
# 50%         6.000000    69.000000        64.000000           2.000000
# 75%         9.000000    84.000000        81.000000           3.000000
# max        60.000000    99.000000        99.000000           4.000000
#
#        Sleep_Hours  Distance_from_Home  Physical_Activity       Health  \
# count  6608.000000         5947.000000        6608.000000  6608.000000
# mean      6.023608           14.857239           2.978208     2.980478
# std       1.992050            8.299310           2.003813     1.426812
# min       3.000000            1.000000           0.000000     1.000000
# 25%       4.000000            8.000000           1.000000     2.000000
# 50%       6.000000           15.000000           3.000000     3.000000
# 75%       8.000000           22.000000           5.000000     4.000000
# max      20.000000           29.000000           6.000000     5.000000
#
#         Exam_Score
# count  6608.000000
# mean     70.530418
# std      12.751706
# min      40.000000
# 25%      61.000000
# 50%      71.000000
# 75%      80.000000
# max      95.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6608 entries, 0 to 6607
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6608 non-null   int64
#  1   Attendance                  6608 non-null   int64
#  2   Previous_Scores             6608 non-null   int64
#  3   Tutoring_Sessions           6608 non-null   int64
#  4   Sleep_Hours                 6608 non-null   int64
#  5   Motivation_Level            6608 non-null   str
#  6   Teacher_Quality             5947 non-null   str
#  7   School_Type                 6608 non-null   str
#  8   Internet_Access             6608 non-null   str
#  9   Family_Income               6608 non-null   str
#  10  Parental_Involvement        6608 non-null   str
#  11  Parental_Education_Level    5947 non-null   str
#  12  Distance_from_Home          5947 non-null   float64
#  13  Physical_Activity           6608 non-null   int64
#  14  Peer_Influence              6608 non-null   str
#  15  Access_to_Resources         6608 non-null   str
#  16  Extracurricular_Activities  6608 non-null   str
#  17  Health                      6608 non-null   int64
#  18  Study_Environment           6608 non-null   str
#  19  Exam_Score                  6608 non-null   int64
# dtypes: float64(1), int64(8), str(11)
# memory usage: 1.0 MB

# %%
df.dtypes
# Out:
# Hours_Studied                   int64
# Attendance                      int64
# Previous_Scores                 int64
# Tutoring_Sessions               int64
# Sleep_Hours                     int64
# Motivation_Level                  str
# Teacher_Quality                   str
# School_Type                       str
# Internet_Access                   str
# Family_Income                     str
# Parental_Involvement              str
# Parental_Education_Level          str
# Distance_from_Home            float64
# Physical_Activity               int64
# Peer_Influence                    str
# Access_to_Resources               str
# Extracurricular_Activities        str
# Health                          int64
# Study_Environment                 str
# Exam_Score                      int64
# dtype: object

# %%
df.isnull()
# Out:
#       Hours_Studied  Attendance  Previous_Scores  Tutoring_Sessions  \
# 0             False       False            False              False
# 1             False       False            False              False
# 2             False       False            False              False
# 3             False       False            False              False
# 4             False       False            False              False
# ...             ...         ...              ...                ...
# 6603          False       False            False              False
# 6604          False       False            False              False
# 6605          False       False            False              False
# 6606          False       False            False              False
# 6607          False       False            False              False
#
#       Sleep_Hours  Motivation_Level  Teacher_Quality  School_Type  \
# 0           False             False            False        False
# 1           False             False            False        False
# 2           False             False            False        False
# 3           False             False            False        False
# 4           False             False            False        False
# ...           ...               ...              ...          ...
# 6603        False             False            False        False
# 6604        False             False            False        False
# 6605        False             False            False        False
# 6606        False             False             True        False
# 6607        False             False            False        False
#
#       Internet_Access  Family_Income  Parental_Involvement  \
# 0               False          False                 False
# 1               False          False                 False
# 2               False          False                 False
# 3               False          False                 False
# 4               False          False                 False
# ...               ...            ...                   ...
# 6603            False          False                 False
# 6604            False          False                 False
# 6605            False          False                 False
# 6606            False          False                 False
# 6607            False          False                 False
#
#       Parental_Education_Level  Distance_from_Home  Physical_Activity  \
# 0                         True               False              False
# 1                        False                True              False
# 2                        False                True              False
# 3                        False               False              False
# 4                        False               False              False
# ...                        ...                 ...                ...
# 6603                     False               False              False
# 6604                     False               False              False
# 6605                     False               False              False
# 6606                     False               False              False
# 6607                     False               False              False
#
#       Peer_Influence  Access_to_Resources  Extracurricular_Activities  Health  \
# 0              False                False                       False   False
# 1              False                False                       False   False
# 2              False                False                       False   False
# 3              False                False                       False   False
# 4              False                False                       False   False
# ...              ...                  ...                         ...     ...
# 6603           False                False                       False   False
# 6604           False                False                       False   False
# 6605           False                False                       False   False
# 6606           False                False                       False   False
# 6607           False                False                       False   False
#
#       Study_Environment  Exam_Score
# 0                 False       False
# 1                 False       False
# 2                 False       False
# 3                 False       False
# 4                 False       False
# ...                 ...         ...
# 6603              False       False
# 6604              False       False
# 6605              False       False
# 6606              False       False
# 6607              False       False
#
# [6608 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# Hours_Studied                   0
# Attendance                      0
# Previous_Scores                 0
# Tutoring_Sessions               0
# Sleep_Hours                     0
# Motivation_Level                0
# Teacher_Quality               661
# School_Type                     0
# Internet_Access                 0
# Family_Income                   0
# Parental_Involvement            0
# Parental_Education_Level      661
# Distance_from_Home            661
# Physical_Activity               0
# Peer_Influence                  0
# Access_to_Resources             0
# Extracurricular_Activities      0
# Health                          0
# Study_Environment               0
# Exam_Score                      0
# dtype: int64

# %%
df.notnull()
# Out:
#       Hours_Studied  Attendance  Previous_Scores  Tutoring_Sessions  \
# 0              True        True             True               True
# 1              True        True             True               True
# 2              True        True             True               True
# 3              True        True             True               True
# 4              True        True             True               True
# ...             ...         ...              ...                ...
# 6603           True        True             True               True
# 6604           True        True             True               True
# 6605           True        True             True               True
# 6606           True        True             True               True
# 6607           True        True             True               True
#
#       Sleep_Hours  Motivation_Level  Teacher_Quality  School_Type  \
# 0            True              True             True         True
# 1            True              True             True         True
# 2            True              True             True         True
# 3            True              True             True         True
# 4            True              True             True         True
# ...           ...               ...              ...          ...
# 6603         True              True             True         True
# 6604         True              True             True         True
# 6605         True              True             True         True
# 6606         True              True            False         True
# 6607         True              True             True         True
#
#       Internet_Access  Family_Income  Parental_Involvement  \
# 0                True           True                  True
# 1                True           True                  True
# 2                True           True                  True
# 3                True           True                  True
# 4                True           True                  True
# ...               ...            ...                   ...
# 6603             True           True                  True
# 6604             True           True                  True
# 6605             True           True                  True
# 6606             True           True                  True
# 6607             True           True                  True
#
#       Parental_Education_Level  Distance_from_Home  Physical_Activity  \
# 0                        False                True               True
# 1                         True               False               True
# 2                         True               False               True
# 3                         True                True               True
# 4                         True                True               True
# ...                        ...                 ...                ...
# 6603                      True                True               True
# 6604                      True                True               True
# 6605                      True                True               True
# 6606                      True                True               True
# 6607                      True                True               True
#
#       Peer_Influence  Access_to_Resources  Extracurricular_Activities  Health  \
# 0               True                 True                        True    True
# 1               True                 True                        True    True
# 2               True                 True                        True    True
# 3               True                 True                        True    True
# 4               True                 True                        True    True
# ...              ...                  ...                         ...     ...
# 6603            True                 True                        True    True
# 6604            True                 True                        True    True
# 6605            True                 True                        True    True
# 6606            True                 True                        True    True
# 6607            True                 True                        True    True
#
#       Study_Environment  Exam_Score
# 0                  True        True
# 1                  True        True
# 2                  True        True
# 3                  True        True
# 4                  True        True
# ...                 ...         ...
# 6603               True        True
# 6604               True        True
# 6605               True        True
# 6606               True        True
# 6607               True        True
#
# [6608 rows x 20 columns]

# %%
df.count()
# Out:
# Hours_Studied                 6608
# Attendance                    6608
# Previous_Scores               6608
# Tutoring_Sessions             6608
# Sleep_Hours                   6608
# Motivation_Level              6608
# Teacher_Quality               5947
# School_Type                   6608
# Internet_Access               6608
# Family_Income                 6608
# Parental_Involvement          6608
# Parental_Education_Level      5947
# Distance_from_Home            5947
# Physical_Activity             6608
# Peer_Influence                6608
# Access_to_Resources           6608
# Extracurricular_Activities    6608
# Health                        6608
# Study_Environment             6608
# Exam_Score                    6608
# dtype: int64

# %%
df['Attendance'].unique()
# Out:
# array([53, 55, 46, 71, 58, 41, 49, 89, 56, 76, 51, 45, 61, 80, 59, 40, 93,
#        86, 92, 97, 57, 84, 72, 62, 65, 52, 54, 83, 66, 75, 94, 96, 44, 77,
#        68, 74, 42, 73, 70, 82, 91, 78, 69, 60, 99, 90, 81, 95, 67, 85, 98,
#        64, 50, 87, 63, 79, 48, 43, 88, 47])

# %%
df['Attendance'].value_counts()
# Out:
# Attendance
# 65    138
# 55    133
# 72    131
# 52    130
# 49    127
# 57    127
# 81    125
# 56    123
# 41    122
# 51    122
# 97    122
# 78    121
# 93    120
# 96    120
# 58    118
# 62    118
# 68    118
# 70    118
# 63    117
# 48    117
# 87    116
# 46    115
# 76    115
# 98    114
# 54    111
# 42    111
# 91    111
# 89    110
# 64    110
# 88    109
# 80    108
# 75    108
# 83    107
# 94    107
# 82    107
# 43    107
# 45    106
# 44    106
# 67    106
# 50    105
# 61    104
# 40    104
# 60    104
# 77    102
# 95    102
# 90    101
# 74    100
# 47     99
# 59     98
# 84     98
# 53     97
# 71     97
# 73     97
# 69     97
# 86     94
# 92     94
# 99     93
# 85     93
# 66     92
# 79     86
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Hours_Studied                 12
# Attendance                    60
# Previous_Scores               70
# Tutoring_Sessions              5
# Sleep_Hours                    8
# Motivation_Level               5
# Teacher_Quality                3
# School_Type                    2
# Internet_Access                2
# Family_Income                  3
# Parental_Involvement           3
# Parental_Education_Level       3
# Distance_from_Home            29
# Physical_Activity              7
# Peer_Influence                 3
# Access_to_Resources            3
# Extracurricular_Activities     2
# Health                         5
# Study_Environment              3
# Exam_Score                    56
# dtype: int64

# %%
import numpy as np
# create realistic score
df['Exam_Score']=(
    df['Hours_Studied']*1.5+
    df['Attendance']*0.3+
    df['Previous_Scores']*0.4+
    df['Sleep_Hours']*1+
    np.random.randint(0,10,size=len(df))
)
# scale to realistic exam range (40 to 95)
df['Exam_Score']=40+(
    (df['Exam_Score']-df['Exam_Score'].min())/
    (df['Exam_Score'].max()-df['Exam_Score'].min())
)*55 
# round values
df['Exam_Score']=df['Exam_Score'].round(1)
# save data set
df.to_csv("Student Performance Data1.csv", index=False)

# %%
df.pd.read_csv('Student Performance Data1 (1).csv')

# %%
# shape of data set
df.shape

# %%
#clumns name
df.columns

# %%
#unique value each columns
df.nunique()

# %%
#categorical columns
print(df['Motivation_Level'].unique())
print(df['Teacher_Quality'].unique())
print(df['School_Type'].unique())

# %%
# missing values
print(df.isnull().sum())
#duplicate rows
print(df.duplicated().sum())

# %%
df['Teacher_Quality']=df['Teacher_Quality'].fillna(df['Teacher_Quality'].mode()[0])
df

# %%
df['Parental_Education_Level']=df['Parental_Education_Level'].fillna(df['Parental_Education_Level'].mode()[0])
df

# %%
df['Distance_from_Home']=df['Distance_from_Home'].fillna(
    df['Distance_from_Home'].median()
)
df

# %%
df['Motivation_Level'].unique()

# %%
df['Motivation_Level']=df['Motivation_Level'].str.lower()
df
df['Motivation_Level']=df['Motivation_Level'].str.capitalize()
df

# %%
df['Motivation_Level']

# %%
num_cols=df.select_dtypes(include=['int64','float64']).columns
num_cols

# %%
# Set figure size
plt.figure(figsize=(18, 12))

#Loop and create subplots
for i, col in enumerate(num_cols, 1):
    plt.subplot(4, 5, i) #adjust grid based on columns
    sns.boxplot(x=df[col])
    
    plt.title(col, fontsize=10)
    plt.xlabel("")
    
#Adjust Layout
plt.tight_layout()

#Add main title
plt.suptitle("Boxplots for Detecting Outliers", fontsize=18, y=1.02)
plt.savefig('boxplot.png')
plt.show()

# %%
Q1 = df['Hours_Studied'].quantile(0.25)
Q3 = df['Hours_Studied'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
df['Hours_Studied'] == np.where(df['Hours_Studied'] > upper, upper, df['Hours_Studied'])
df
df['Hours_Studied'] == np.where(df['Hours_Studied'] < lower, lower, df ['Hours_Studied'])
df

# %%
Q1 = df['Sleep_Hours'].quantile(0.25)
Q3 = df['Sleep_Hours'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
df['Sleep_Hours'] == np.where(df['Sleep_Hours'] > upper, upper, df['Sleep_Hours'])
df
df['Sleep_Hours'] == np.where(df['Sleep_Hours'] < lower, lower, df ['Sleep_Hours'])
df

# %%
plt.style.use('fivethirtyeight') #modern style
sns.set_palette('set2')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))

# Calculate mean
grouped = df.groupby('Motivation_Level')['Exam_Score'].mean()

# Plot
plt.bar(grouped.index, grouped.values)

plt.title("Motivation Level vs Exam Score (Mean)", fontsize=14, fontweight='bold')
plt.xlabel("Motivation Level")
plt.ylabel("Average Exam Score")

plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.boxplot(x=df['Exam_Score'],color='skyblue',linewidth=2)

plt.title("Boxplot of Exam score",fontsize=13,fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(
    df['Sleep_Hours'],
    df['Exam_Score'],
    color='green',
    alpha=0.6
)

plt.title("Sleep hours vs Exam Score",fontsize=14,fontweight='bold')
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")

plt.grid(True, linestyle='--',alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(
    df['Hours_Studied'], 
    df['Exam_Score'], 
    color='purple', 
    alpha=0.6, 
    edgecolor='black'
)

plt.title("Study Hours vs Exam Score", fontsize=14, fontweight='bold')
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")

plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.boxplot(
    x='Motivation_Level',
    y='Exam_Score',
    hue='Motivation_Level',
    data=df,
    palette='coolwarm',
    legend=False
)

plt.title("Motivation Level vs Exam Score (Better Insight)", fontsize=14, fontweight='bold')

plt.show()

# %%
sns.stripplot(
    x='Motivation_Level',
    y='Exam_Score',
    data=df,
    jitter=True
)
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='Exam_Score'>

# %%
plt.figure(figsize=(7,5))

plt.scatter(
    df['Hours_Studied'],
    df['Exam_Score'],
    alpha=0.6
)

plt.title("Hours Studied vs Exam Score", fontsize=14, fontweight='bold')
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")

plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(5,5))

# Convert categories to numbers
mapping = {'Low': 1, 'Medium': 2, 'High': 3}
x = df['Motivation_Level'].map(mapping)

plt.scatter(x, df['Exam_Score'], alpha=0.5)

plt.xticks([1,2,3], ['Low', 'Medium', 'High'])

plt.title("Motivation vs Exam Score (Scatter)", fontsize=14, fontweight='bold')
plt.xlabel("Motivation Level")
plt.ylabel("Exam Score")

plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Exam_Score'], bins=20, edgecolor='black', alpha=0.7)

plt.title("Distribution of Exam Score", fontsize=14, fontweight='bold')
plt.xlabel("Exam Score")
plt.ylabel("Frequency")

plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.scatter(
    df['Hours_Studied'],
    df['Exam_Score'],
    alpha=0.6
)

plt.title("Hours Studied vs Exam Score", fontsize=14, fontweight='bold')
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")

plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %%
sorted_df = df.sort_values(by='Hours_Studied')

plt.figure(figsize=(7,5))

plt.plot(
    sorted_df['Hours_Studied'],
    sorted_df['Exam_Score']
)

plt.title("Trend: Study Hours vs Score", fontsize=14, fontweight='bold')
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")

plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.boxplot(
    x='School_Type',
    y='Exam_Score',
    data=df
)

plt.title("School Type vs Exam Score", fontsize=14, fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.countplot(
    x='Motivation_Level',
    data=df
)

plt.title("Count of Students by Motivation Level", fontsize=14, fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.violinplot(
    x='Parental_Involvement',
    y='Exam_Score',
    data=df,
    inner='box'   # shows median + quartiles inside
)

plt.title("Parental Involvement vs Exam Score", fontsize=14, fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap", fontsize=14, fontweight='bold')

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.kdeplot(
    df['Exam_Score'],
    fill=True
)

plt.title("Density Plot of Exam Score", fontsize=14, fontweight='bold')

plt.show()

# %%
df.corr(numeric_only=True)['Exam_Score'].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.corr(numeric_only=True)['Exam_Score'].sort_values(ascending=False)
#
# NameError: name 'df' is not defined
